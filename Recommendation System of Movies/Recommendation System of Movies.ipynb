# %% [markdown]
# # Proyecto 6: Sistemas de recomendación

# %% [markdown]
# ## Dataset

# %% [markdown]
# El dataset que vamos a usar en este proyecto es el del proyecto [MovieLens](http://grouplens.org/datasets/movielens/). Estos son relevados por el grupo de investigación GroupLens de la Universidad de Minnesota. Vamos a usar la versión 100K.

# %% [markdown]
# Está basado en un sistema de rating de 5 estrellas y texto libre para tags a partir del servicio de recomendaciones MovieLens. Contiene 100.000 ratings para 1.682 películas. Los datos fueron creados por 943 usuarios.

# %% [markdown]
# En el [Readme](http://files.grouplens.org/datasets/movielens/ml-100k-README.txt) del dataset se puede encontrar información adicional. A continuación vamos a describir cada uno de ellos.

# %% [markdown]
# ### Ratings (u.data)
#
# Cada línea representa el rating para una película para un usuario. Los ratings están basados en un sistema de 5 estrellas, con una salto de 0.5 estrellas. Los timestamps están expresados en segundos desde la medianoche de 01/1970 (UTC). El formato es:
#
# `user id | item id | rating | timestamp`

# %% [markdown]
# ### Usuarios (u.users)
#
# Cada línea del archivo representa un usuario. Se incluye información demográfica. El formato es:
#
# `user id | age | gender | occupation | zip code`

# %% [markdown]
# ### Películas (u.item)
#
# Cada línea corresponde a una película. Puede haber inconsistencias en los nombres. El formato es:
#
# `movie id | movie title | release date | video release date | IMDb URL | generos`
#
#
#
# Las columnas con los generos son binarias indicando la presencia o ausencia de cada uno en la película. Los géneros pueden ser:
#
# * Action
# * Adventure
# * Animation
# * Children's
# * Comedy
# * Crime
# * Documentary
# * Drama
# * Fantasy
# * Film-Noir
# * Horror
# * Musical
# * Mystery
# * Romance
# * Sci-Fi
# * Thriller
# * War
# * Western
# * unknown

# %% [markdown]
# ## Experimentación

# %% [markdown]
# Durante todo este proyecto vamos a utilizar la librería `surprise` para llevar a cabo las experimentaciones.
#
# Como se mencionó en clase, las implementaciones en esta librería tiene algunas mejoras respecto de las estrategias convencionales como SVD. Esto se traduce en una mayor cantidad de parámetros para optimizar.

# %% [markdown]
# Vamos a levantar los datos. En primer lugar, definamos el formato para poder leer los datos.
#
# **1) Utilizar** el `Reader` con el parámetro `line_format` igual a `'user item rating timestamp'` y `sep` como `'\t'`. Guardarlo en una variable `reader`.

# %%
from surprise import Dataset
from surprise import Reader

reader = Reader(line_format='user item rating timestamp', sep='\t')

# %% [markdown]
# Utilizando este `reader` cargar los datos:

# %%
data = Dataset.load_from_file('dataset/ml-100k/u.data',reader=reader)

# %%
import pandas as pd
u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']
users = pd.read_csv('dataset/ml-100k/u.user', sep='|', names=u_cols,
                    encoding='latin-1', parse_dates=True) 

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('dataset/ml-100k/u.data', sep='\t', names=r_cols,
                      encoding='latin-1')

m_cols = ['movie_id', 'title', 'release_date', 'video_release_date', 'imdb_url']
movies = pd.read_csv('dataset/ml-100k/u.item', sep='|', names=m_cols, usecols=range(5),
                     encoding='latin-1')

movie_ratings = pd.merge(movies, ratings)
df = pd.merge(movie_ratings, users)

df.head(5)
# Out:
#    movie_id                  title release_date  video_release_date  \
# 0         1       Toy Story (1995)  01-Jan-1995                 NaN
# 1         4      Get Shorty (1995)  01-Jan-1995                 NaN
# 2         5         Copycat (1995)  01-Jan-1995                 NaN
# 3         7  Twelve Monkeys (1995)  01-Jan-1995                 NaN
# 4         8            Babe (1995)  01-Jan-1995                 NaN
#
#                                             imdb_url  user_id  rating  \
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...      308       4
# 1  http://us.imdb.com/M/title-exact?Get%20Shorty%...      308       5
# 2  http://us.imdb.com/M/title-exact?Copycat%20(1995)      308       4
# 3  http://us.imdb.com/M/title-exact?Twelve%20Monk...      308       4
# 4     http://us.imdb.com/M/title-exact?Babe%20(1995)      308       5
#
#    unix_timestamp  age sex occupation zip_code
# 0       887736532   60   M    retired    95076
# 1       887737890   60   M    retired    95076
# 2       887739608   60   M    retired    95076
# 3       887738847   60   M    retired    95076
# 4       887736696   60   M    retired    95076

# %%
movies.head()
# Out:
#    movie_id              title release_date  video_release_date  \
# 0         1   Toy Story (1995)  01-Jan-1995                 NaN
# 1         2   GoldenEye (1995)  01-Jan-1995                 NaN
# 2         3  Four Rooms (1995)  01-Jan-1995                 NaN
# 3         4  Get Shorty (1995)  01-Jan-1995                 NaN
# 4         5     Copycat (1995)  01-Jan-1995                 NaN
#
#                                             imdb_url
# 0  http://us.imdb.com/M/title-exact?Toy%20Story%2...
# 1  http://us.imdb.com/M/title-exact?GoldenEye%20(...
# 2  http://us.imdb.com/M/title-exact?Four%20Rooms%...
# 3  http://us.imdb.com/M/title-exact?Get%20Shorty%...
# 4  http://us.imdb.com/M/title-exact?Copycat%20(1995)

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  unix_timestamp
# 0      196       242       3       881250949
# 1      186       302       3       891717742
# 2       22       377       1       878887116
# 3      244        51       2       880606923
# 4      166       346       1       886397596

# %%
users.head()
# Out:
#    user_id  age sex  occupation zip_code
# 0        1   24   M  technician    85711
# 1        2   53   F       other    94043
# 2        3   23   M      writer    32067
# 3        4   24   M  technician    43537
# 4        5   33   F       other    15213

# %% [markdown]
# __2) Ejecutar una corrida inicial usando cross validation y el algoritmo SVD (5 folds). Imprimir los RMSE de testing.__

# %%
from surprise import SVD
from surprise.model_selection import cross_validate

svd=SVD()
cv=cross_validate(svd,data,cv=5,verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9366  0.9292  0.9384  0.9396  0.9411  0.9370  0.0041
# MAE (testset)     0.7401  0.7332  0.7370  0.7437  0.7426  0.7393  0.0038
# Fit time          4.62    4.70    5.10    4.79    4.52    4.74    0.20
# Test time         0.23    0.18    0.14    0.13    0.17    0.17    0.04

# %%
print(cv['test_rmse'])
# Out:
# [0.93663831 0.92924228 0.938404   0.93957721 0.94111044]

# %% [markdown]
# __3) Evaluar el RMSE (promedio de cross validation) de testing de acuerdo a la cantidad de factores en SVD.__

# %%
import numpy as np
rmse_test_means = []

factors = [5,100,200,500,1000]
for factor in factors:
    algo = SVD(n_factors=factor)
    cv = cross_validate(algo, data, measures=['RMSE'],  cv=3, verbose=False)
    rmse_test_means.append(np.mean(cv['test_rmse']))
rmse_test_means
# Out:
# [0.943035022599591,
#  0.948010817448473,
#  0.9521673583302842,
#  0.964141536453436,
#  0.9802846996449176]

# %% [markdown]
# __4) Graficar los promedios RMSE del conjunto de testing de acuerdo a la cantidad de factores en SVD.__

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.plot(factors, rmse_test_means, label='RMSE Testing')
plt.ylim((0.92, 1.0))
plt.legend(loc="best")
plt.title("RMSE para algoritmo SVD según cantidad de factores.")
plt.show()

# %% [markdown]
# __5) Usando GridSearch, encontrar el mejor estimador usando SVD con 500 factores. Imprimir el mejor rmse. Utilizar `refit` para obtener obtener el mejor estimador ya ajustado como resultado.__
#
# Utilizar el espacio de parámetros:
# * n_epochs: [5, 10]
# * lr_all: [0.002, 0.005]
# * reg_all: [0.4, 0.6]

# %%
from surprise.model_selection import GridSearchCV

param_grid = {'n_factors':[500],'n_epochs': [5, 10], 'lr_all': [0.002, 0.005],
              'reg_all': [0.4, 0.6]}
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3,refit=True)

gs.fit(data)

# %%
print(gs.best_params['rmse'])

# %%
print(gs.best_score['rmse'])

# %% [markdown]
# __6) Obtener una predicción para el usuario 321 para la película Titanic.__

# %%
print(users.iloc[320])

# %%
print(movies.iloc[312])

# %%
movies.dtype

# %%
from surprise.model_selection import train_test_split

trainset, testset = train_test_split(data, test_size=.25)
algo.fit(trainset)
predictions = algo.test(testset)

# %%
predictions
# Out:
# [Prediction(uid='650', iid='195', r_ui=4.0, est=3.678435874948563, details={'was_impossible': False}),
#  Prediction(uid='6', iid='494', r_ui=4.0, est=4.053437582935192, details={'was_impossible': False}),
#  Prediction(uid='500', iid='781', r_ui=3.0, est=2.861798361639699, details={'was_impossible': False}),
#  Prediction(uid='59', iid='447', r_ui=5.0, est=3.602318533401852, details={'was_impossible': False}),
#  Prediction(uid='188', iid='1263', r_ui=3.0, est=3.7550667461903053, details={'was_impossible': False}),
#  Prediction(uid='606', iid='79', r_ui=3.0, est=4.370535258029995, details={'was_impossible': False}),
#  Prediction(uid='922', iid='1079', r_ui=1.0, est=2.47985841899803, details={'was_impossible': False}),
#  Prediction(uid='868', iid='1480', r_ui=1.0, est=2.37540735328954, details={'was_impossible': False}),
#  Prediction(uid='146', iid='301', r_ui=2.0, est=3.3954723208580164, details={'was_impossible': False}),
#  Prediction(uid='345', iid='696', r_ui=3.0, est=3.0928797540259585, details={'was_impossible': False}),
#  Prediction(uid='87', iid='1049', r_ui=3.0, est=3.901232539220148, details={'was_impossible': False}),
#  Prediction(uid='715', iid='168', r_ui=4.0, est=3.950290120409673, details={'was_impossible': False}),
#  Prediction(uid='506', iid='568', r_ui=5.0, est=4.19221662579382, details={'was_impossible': False}),
#  Prediction(uid='634', iid='322', r_ui=3.0, est=3.7049672164124283, details={'was_impossible': False}),
#  Prediction(uid='804', iid='434', r_ui=4.0, est=3.726929907682154, details={'was_impossible': False}),
#  Prediction(uid='687', iid='313', r_ui=5.0, est=4.311640303459679, details={'was_impossible': False}),
#  Prediction(uid='834', iid='744', r_ui=4.0, est=4.113346334465253, details={'was_impossible': False}),
#  Prediction(uid='645', iid='184', r_ui=3.0, est=3.079467098916823, details={'was_impossible': False}),
#  Prediction(uid='393', iid='223', r_ui=4.0, est=3.7882938530355412, details={'was_impossible': False}),
#  Prediction(uid='566', iid='228', r_ui=2.0, est=3.3942015386616458, details={'was_impossible': False}),
#  Prediction(uid='916', iid='164', r_ui=4.0, est=3.7344928841965097, details={'was_impossible': False}),
#  Prediction(uid='892', iid='636', r_ui=4.0, est=3.8079217333189552, details={'was_impossible': False}),
#  Prediction(uid='463', iid='1606', r_ui=2.0, est=2.9549795029006893, details={'was_impossible': False}),
#  Prediction(uid='795', iid='514', r_ui=4.0, est=3.8551026218940523, details={'was_impossible': False}),
#  Prediction(uid='655', iid='417', r_ui=2.0, est=2.8843354477186267, details={'was_impossible': False}),
#  Prediction(uid='874', iid='100', r_ui=4.0, est=4.634583949930111, details={'was_impossible': False}),
#  Prediction(uid='106', iid='647', r_ui=3.0, est=3.92333232725116, details={'was_impossible': False}),
#  Prediction(uid='387', iid='286', r_ui=2.0, est=2.996963931398989, details={'was_impossible': False}),
#  Prediction(uid='721', iid='174', r_ui=5.0, est=3.9362000369147343, details={'was_impossible': False}),
#  Prediction(uid='500', iid='559', r_ui=4.0, est=2.8491668199467135, details={'was_impossible': False}),
#  Prediction(uid='292', iid='265', r_ui=4.0, est=4.841182528837063, details={'was_impossible': False}),
#  Prediction(uid='43', iid='781', r_ui=3.0, est=3.3082459063360337, details={'was_impossible': False}),
#  Prediction(uid='805', iid='423', r_ui=1.0, est=3.4045028470789145, details={'was_impossible': False}),
#  Prediction(uid='458', iid='273', r_ui=4.0, est=3.1180278771751126, details={'was_impossible': False}),
#  Prediction(uid='123', iid='294', r_ui=1.0, est=2.6803196557409947, details={'was_impossible': False}),
#  Prediction(uid='59', iid='190', r_ui=5.0, est=3.8196915485199385, details={'was_impossible': False}),
#  Prediction(uid='794', iid='24', r_ui=5.0, est=3.2562826181617135, details={'was_impossible': False}),
#  Prediction(uid='488', iid='358', r_ui=3.0, est=1.8613657563789643, details={'was_impossible': False}),
#  Prediction(uid='546', iid='234', r_ui=4.0, est=3.871650385860185, details={'was_impossible': False}),
#  Prediction(uid='594', iid='515', r_ui=5.0, est=3.7019751799373717, details={'was_impossible': False}),
#  Prediction(uid='870', iid='1014', r_ui=2.0, est=3.0799462532711592, details={'was_impossible': False}),
#  Prediction(uid='882', iid='660', r_ui=3.0, est=3.8219983932759725, details={'was_impossible': False}),
#  Prediction(uid='883', iid='277', r_ui=4.0, est=3.8391180762436345, details={'was_impossible': False}),
#  Prediction(uid='691', iid='243', r_ui=1.0, est=3.4110905203447124, details={'was_impossible': False}),
#  Prediction(uid='170', iid='304', r_ui=4.0, est=3.6741974109653435, details={'was_impossible': False}),
#  Prediction(uid='301', iid='409', r_ui=4.0, est=3.462721066890798, details={'was_impossible': False}),
#  Prediction(uid='727', iid='114', r_ui=5.0, est=3.341127147334671, details={'was_impossible': False}),
#  Prediction(uid='417', iid='64', r_ui=5.0, est=4.625608696975421, details={'was_impossible': False}),
#  Prediction(uid='479', iid='235', r_ui=3.0, est=2.777947865546306, details={'was_impossible': False}),
#  Prediction(uid='450', iid='328', r_ui=4.0, est=3.4743160912687787, details={'was_impossible': False}),
#  Prediction(uid='577', iid='1271', r_ui=3.0, est=3.2353518827429246, details={'was_impossible': False}),
#  Prediction(uid='435', iid='684', r_ui=4.0, est=3.6820547072931684, details={'was_impossible': False}),
#  Prediction(uid='643', iid='663', r_ui=4.0, est=3.918736776898898, details={'was_impossible': False}),
#  Prediction(uid='770', iid='334', r_ui=5.0, est=4.291773054045071, details={'was_impossible': False}),
#  Prediction(uid='214', iid='185', r_ui=5.0, est=4.087088776918522, details={'was_impossible': False}),
#  Prediction(uid='5', iid='228', r_ui=5.0, est=3.214458880403576, details={'was_impossible': False}),
#  Prediction(uid='697', iid='301', r_ui=5.0, est=3.5474144121515017, details={'was_impossible': False}),
#  Prediction(uid='405', iid='621', r_ui=1.0, est=2.240912760574404, details={'was_impossible': False}),
#  Prediction(uid='693', iid='215', r_ui=4.0, est=2.953609187996388, details={'was_impossible': False}),
#  Prediction(uid='381', iid='961', r_ui=3.0, est=4.334086361559405, details={'was_impossible': False}),
#  Prediction(uid='537', iid='690', r_ui=2.0, est=2.4054443933408405, details={'was_impossible': False}),
#  Prediction(uid='880', iid='375', r_ui=1.0, est=2.6109393918713297, details={'was_impossible': False}),
#  Prediction(uid='774', iid='421', r_ui=1.0, est=2.123506522259288, details={'was_impossible': False}),
#  Prediction(uid='548', iid='1025', r_ui=4.0, est=3.8736846911930565, details={'was_impossible': False}),
#  Prediction(uid='447', iid='367', r_ui=3.0, est=4.040953154102013, details={'was_impossible': False}),
#  Prediction(uid='314', iid='655', r_ui=4.0, est=4.287402044752553, details={'was_impossible': False}),
#  Prediction(uid='76', iid='1154', r_ui=5.0, est=3.5424609187693883, details={'was_impossible': False}),
#  Prediction(uid='670', iid='228', r_ui=5.0, est=3.853310026077935, details={'was_impossible': False}),
#  Prediction(uid='910', iid='127', r_ui=5.0, est=3.6179987658560098, details={'was_impossible': False}),
#  Prediction(uid='713', iid='286', r_ui=3.0, est=3.383180639074779, details={'was_impossible': False}),
#  Prediction(uid='254', iid='378', r_ui=3.0, est=3.141220908642543, details={'was_impossible': False}),
#  Prediction(uid='629', iid='880', r_ui=4.0, est=3.875114990627107, details={'was_impossible': False}),
#  Prediction(uid='308', iid='1252', r_ui=3.0, est=3.544410732582076, details={'was_impossible': False}),
#  Prediction(uid='479', iid='50', r_ui=4.0, est=4.352148956585994, details={'was_impossible': False}),
#  Prediction(uid='734', iid='222', r_ui=1.0, est=4.073984410667749, details={'was_impossible': False}),
#  Prediction(uid='902', iid='246', r_ui=1.0, est=4.137931290728307, details={'was_impossible': False}),
#  Prediction(uid='474', iid='66', r_ui=4.0, est=4.062712692348478, details={'was_impossible': False}),
#  Prediction(uid='392', iid='269', r_ui=5.0, est=4.309062732552784, details={'was_impossible': False}),
#  Prediction(uid='843', iid='28', r_ui=3.0, est=3.2875848754294847, details={'was_impossible': False}),
#  Prediction(uid='642', iid='726', r_ui=2.0, est=3.820235133760437, details={'was_impossible': False}),
#  Prediction(uid='576', iid='280', r_ui=5.0, est=2.9368398889944802, details={'was_impossible': False}),
#  Prediction(uid='383', iid='641', r_ui=4.0, est=4.077602878084194, details={'was_impossible': False}),
#  Prediction(uid='450', iid='395', r_ui=3.0, est=3.233338239777976, details={'was_impossible': False}),
#  Prediction(uid='374', iid='1513', r_ui=2.0, est=2.993472890724158, details={'was_impossible': False}),
#  Prediction(uid='188', iid='199', r_ui=4.0, est=3.92863875313909, details={'was_impossible': False}),
#  Prediction(uid='303', iid='41', r_ui=5.0, est=3.1685541041631957, details={'was_impossible': False}),
#  Prediction(uid='466', iid='1607', r_ui=5.0, est=2.8022261564841755, details={'was_impossible': False}),
#  Prediction(uid='863', iid='749', r_ui=2.0, est=3.547418499703072, details={'was_impossible': False}),
#  Prediction(uid='780', iid='186', r_ui=4.0, est=3.954507427759228, details={'was_impossible': False}),
#  Prediction(uid='94', iid='179', r_ui=5.0, est=4.3629917886382765, details={'was_impossible': False}),
#  Prediction(uid='459', iid='1190', r_ui=4.0, est=3.4070011312869353, details={'was_impossible': False}),
#  Prediction(uid='622', iid='169', r_ui=5.0, est=4.503640510855694, details={'was_impossible': False}),
#  Prediction(uid='280', iid='128', r_ui=3.0, est=2.929200587530614, details={'was_impossible': False}),
#  Prediction(uid='934', iid='1425', r_ui=1.0, est=3.142308595316145, details={'was_impossible': False}),
#  Prediction(uid='621', iid='79', r_ui=5.0, est=3.870910066130367, details={'was_impossible': False}),
#  Prediction(uid='41', iid='31', r_ui=3.0, est=3.4969882890754707, details={'was_impossible': False}),
#  Prediction(uid='389', iid='550', r_ui=3.0, est=3.4824647001438875, details={'was_impossible': False}),
#  Prediction(uid='514', iid='202', r_ui=4.0, est=3.9281069953948795, details={'was_impossible': False}),
#  Prediction(uid='663', iid='985', r_ui=3.0, est=3.7791974648669973, details={'was_impossible': False}),
#  Prediction(uid='269', iid='1020', r_ui=4.0, est=3.4558792697678737, details={'was_impossible': False}),
#  Prediction(uid='711', iid='343', r_ui=3.0, est=3.292212167944742, details={'was_impossible': False}),
#  Prediction(uid='516', iid='199', r_ui=3.0, est=4.375301432757994, details={'was_impossible': False}),
#  Prediction(uid='224', iid='991', r_ui=1.0, est=2.381684274978746, details={'was_impossible': False}),
#  Prediction(uid='334', iid='300', r_ui=3.0, est=3.0075036404533666, details={'was_impossible': False}),
#  Prediction(uid='16', iid='152', r_ui=4.0, est=3.8458850116145635, details={'was_impossible': False}),
#  Prediction(uid='767', iid='344', r_ui=4.0, est=4.113917830292317, details={'was_impossible': False}),
#  Prediction(uid='200', iid='549', r_ui=4.0, est=4.174175956308531, details={'was_impossible': False}),
#  Prediction(uid='299', iid='270', r_ui=4.0, est=3.302057559710659, details={'was_impossible': False}),
#  Prediction(uid='291', iid='28', r_ui=4.0, est=4.127835098144249, details={'was_impossible': False}),
#  Prediction(uid='700', iid='423', r_ui=4.0, est=3.952657605073291, details={'was_impossible': False}),
#  Prediction(uid='213', iid='55', r_ui=5.0, est=4.44008828119528, details={'was_impossible': False}),
#  Prediction(uid='443', iid='313', r_ui=4.0, est=3.4938562681258793, details={'was_impossible': False}),
#  Prediction(uid='302', iid='271', r_ui=4.0, est=3.248021202618459, details={'was_impossible': False}),
#  Prediction(uid='747', iid='87', r_ui=5.0, est=4.3937968450442995, details={'was_impossible': False}),
#  Prediction(uid='387', iid='528', r_ui=4.0, est=4.379082796458055, details={'was_impossible': False}),
#  Prediction(uid='311', iid='528', r_ui=4.0, est=4.315541178163156, details={'was_impossible': False}),
#  Prediction(uid='916', iid='226', r_ui=3.0, est=2.91335578098969, details={'was_impossible': False}),
#  Prediction(uid='823', iid='631', r_ui=4.0, est=3.9206591303509684, details={'was_impossible': False}),
#  Prediction(uid='438', iid='866', r_ui=5.0, est=3.519595948032717, details={'was_impossible': False}),
#  Prediction(uid='286', iid='535', r_ui=5.0, est=3.798266643394058, details={'was_impossible': False}),
#  Prediction(uid='394', iid='229', r_ui=3.0, est=3.2246281520314044, details={'was_impossible': False}),
#  Prediction(uid='526', iid='544', r_ui=1.0, est=3.285654616779664, details={'was_impossible': False}),
#  Prediction(uid='85', iid='1021', r_ui=3.0, est=3.372710557733636, details={'was_impossible': False}),
#  Prediction(uid='626', iid='272', r_ui=5.0, est=3.7390688700430244, details={'was_impossible': False}),
#  Prediction(uid='108', iid='931', r_ui=2.0, est=2.4656368887684774, details={'was_impossible': False}),
#  Prediction(uid='251', iid='476', r_ui=2.0, est=3.640445308227337, details={'was_impossible': False}),
#  Prediction(uid='577', iid='1', r_ui=5.0, est=4.029958768632712, details={'was_impossible': False}),
#  Prediction(uid='521', iid='204', r_ui=4.0, est=3.2902865665928336, details={'was_impossible': False}),
#  Prediction(uid='429', iid='936', r_ui=4.0, est=3.9729552021011485, details={'was_impossible': False}),
#  Prediction(uid='437', iid='583', r_ui=1.0, est=3.4259586288083113, details={'was_impossible': False}),
#  Prediction(uid='176', iid='257', r_ui=1.0, est=4.681588430496314, details={'was_impossible': False}),
#  Prediction(uid='7', iid='470', r_ui=3.0, est=4.433768745258401, details={'was_impossible': False}),
#  Prediction(uid='588', iid='225', r_ui=5.0, est=3.575413366693157, details={'was_impossible': False}),
#  Prediction(uid='151', iid='1006', r_ui=1.0, est=3.4824004860876507, details={'was_impossible': False}),
#  Prediction(uid='701', iid='315', r_ui=5.0, est=4.238383851611897, details={'was_impossible': False}),
#  Prediction(uid='918', iid='179', r_ui=2.0, est=3.5781078826542125, details={'was_impossible': False}),
#  Prediction(uid='264', iid='98', r_ui=5.0, est=4.663093048651273, details={'was_impossible': False}),
#  Prediction(uid='730', iid='15', r_ui=4.0, est=3.6674271099134796, details={'was_impossible': False}),
#  Prediction(uid='43', iid='211', r_ui=4.0, est=3.9826533504635657, details={'was_impossible': False}),
#  Prediction(uid='201', iid='233', r_ui=4.0, est=2.339299590191202, details={'was_impossible': False}),
#  Prediction(uid='346', iid='157', r_ui=3.0, est=3.6385449468271642, details={'was_impossible': False}),
#  Prediction(uid='255', iid='273', r_ui=2.0, est=2.848338736317914, details={'was_impossible': False}),
#  Prediction(uid='795', iid='39', r_ui=4.0, est=3.3977257983094145, details={'was_impossible': False}),
#  Prediction(uid='404', iid='270', r_ui=4.0, est=3.6997839649907256, details={'was_impossible': False}),
#  Prediction(uid='381', iid='418', r_ui=3.0, est=3.76044829646111, details={'was_impossible': False}),
#  Prediction(uid='301', iid='515', r_ui=3.0, est=4.257021276368199, details={'was_impossible': False}),
#  Prediction(uid='13', iid='836', r_ui=2.0, est=3.354764340635495, details={'was_impossible': False}),
#  Prediction(uid='194', iid='86', r_ui=3.0, est=3.7831088986703363, details={'was_impossible': False}),
#  Prediction(uid='286', iid='96', r_ui=4.0, est=3.6380908783431556, details={'was_impossible': False}),
#  Prediction(uid='101', iid='472', r_ui=3.0, est=2.9706760254036464, details={'was_impossible': False}),
#  Prediction(uid='70', iid='546', r_ui=2.0, est=2.44856769567935, details={'was_impossible': False}),
#  Prediction(uid='671', iid='504', r_ui=4.0, est=3.2601708940873695, details={'was_impossible': False}),
#  Prediction(uid='541', iid='756', r_ui=4.0, est=2.8864358634122573, details={'was_impossible': False}),
#  Prediction(uid='327', iid='154', r_ui=4.0, est=3.11479519737947, details={'was_impossible': False}),
#  Prediction(uid='731', iid='427', r_ui=5.0, est=3.5761980580509056, details={'was_impossible': False}),
#  Prediction(uid='472', iid='385', r_ui=5.0, est=4.517613375345861, details={'was_impossible': False}),
#  Prediction(uid='215', iid='1063', r_ui=5.0, est=3.15837007287593, details={'was_impossible': False}),
#  Prediction(uid='324', iid='258', r_ui=4.0, est=4.036025116814689, details={'was_impossible': False}),
#  Prediction(uid='188', iid='185', r_ui=4.0, est=4.420654979909158, details={'was_impossible': False}),
#  Prediction(uid='887', iid='578', r_ui=4.0, est=4.029286832052741, details={'was_impossible': False}),
#  Prediction(uid='426', iid='174', r_ui=3.0, est=4.318541181865419, details={'was_impossible': False}),
#  Prediction(uid='85', iid='464', r_ui=5.0, est=3.623304456775712, details={'was_impossible': False}),
#  Prediction(uid='621', iid='250', r_ui=4.0, est=3.8550802772838604, details={'was_impossible': False}),
#  Prediction(uid='280', iid='56', r_ui=5.0, est=4.616602854394021, details={'was_impossible': False}),
#  Prediction(uid='347', iid='290', r_ui=3.0, est=3.134766060616614, details={'was_impossible': False}),
#  Prediction(uid='311', iid='22', r_ui=4.0, est=4.611289259175637, details={'was_impossible': False}),
#  Prediction(uid='618', iid='699', r_ui=3.0, est=3.0693972031570005, details={'was_impossible': False}),
#  Prediction(uid='913', iid='191', r_ui=5.0, est=4.182785286296371, details={'was_impossible': False}),
#  Prediction(uid='145', iid='11', r_ui=5.0, est=2.9647527400794313, details={'was_impossible': False}),
#  Prediction(uid='429', iid='230', r_ui=2.0, est=3.2225337855254055, details={'was_impossible': False}),
#  Prediction(uid='472', iid='916', r_ui=5.0, est=4.124261881391244, details={'was_impossible': False}),
#  Prediction(uid='551', iid='274', r_ui=2.0, est=4.238541871286213, details={'was_impossible': False}),
#  Prediction(uid='653', iid='575', r_ui=1.0, est=2.1439936783305225, details={'was_impossible': False}),
#  Prediction(uid='238', iid='181', r_ui=3.0, est=4.313574605866909, details={'was_impossible': False}),
#  Prediction(uid='323', iid='876', r_ui=2.0, est=2.8843862779919722, details={'was_impossible': False}),
#  Prediction(uid='253', iid='679', r_ui=3.0, est=3.3272854839836308, details={'was_impossible': False}),
#  Prediction(uid='450', iid='521', r_ui=4.0, est=3.759210965399176, details={'was_impossible': False}),
#  Prediction(uid='353', iid='898', r_ui=2.0, est=3.1839130820488206, details={'was_impossible': False}),
#  Prediction(uid='1', iid='182', r_ui=4.0, est=4.313379792142632, details={'was_impossible': False}),
#  Prediction(uid='256', iid='86', r_ui=5.0, est=4.331359700472856, details={'was_impossible': False}),
#  Prediction(uid='707', iid='1211', r_ui=4.0, est=2.8473928091697323, details={'was_impossible': False}),
#  Prediction(uid='125', iid='116', r_ui=4.0, est=3.807282732831018, details={'was_impossible': False}),
#  Prediction(uid='704', iid='210', r_ui=4.0, est=3.7798460392399367, details={'was_impossible': False}),
#  Prediction(uid='747', iid='500', r_ui=4.0, est=3.8266766320645105, details={'was_impossible': False}),
#  Prediction(uid='221', iid='174', r_ui=4.0, est=4.682997962700896, details={'was_impossible': False}),
#  Prediction(uid='535', iid='639', r_ui=4.0, est=3.554772437470309, details={'was_impossible': False}),
#  Prediction(uid='308', iid='319', r_ui=4.0, est=3.5457555387000412, details={'was_impossible': False}),
#  Prediction(uid='758', iid='223', r_ui=5.0, est=4.854448815458347, details={'was_impossible': False}),
#  Prediction(uid='627', iid='33', r_ui=1.0, est=3.693481071597773, details={'was_impossible': False}),
#  Prediction(uid='435', iid='229', r_ui=2.0, est=2.9561199239644482, details={'was_impossible': False}),
#  Prediction(uid='932', iid='528', r_ui=5.0, est=4.149352878659744, details={'was_impossible': False}),
#  Prediction(uid='917', iid='246', r_ui=4.0, est=3.71611999896402, details={'was_impossible': False}),
#  Prediction(uid='642', iid='597', r_ui=4.0, est=3.7961494811904024, details={'was_impossible': False}),
#  Prediction(uid='320', iid='1157', r_ui=4.0, est=3.553062201476951, details={'was_impossible': False}),
#  Prediction(uid='568', iid='659', r_ui=3.0, est=3.6997566981045305, details={'was_impossible': False}),
#  Prediction(uid='844', iid='251', r_ui=4.0, est=3.8304068889324276, details={'was_impossible': False}),
#  Prediction(uid='332', iid='313', r_ui=5.0, est=4.771095164137636, details={'was_impossible': False}),
#  Prediction(uid='23', iid='222', r_ui=4.0, est=3.7747743335982116, details={'was_impossible': False}),
#  Prediction(uid='357', iid='473', r_ui=3.0, est=3.88893969732375, details={'was_impossible': False}),
#  Prediction(uid='773', iid='216', r_ui=4.0, est=3.7208930385480286, details={'was_impossible': False}),
#  Prediction(uid='576', iid='435', r_ui=4.0, est=4.04953479910989, details={'was_impossible': False}),
#  Prediction(uid='774', iid='105', r_ui=1.0, est=1.6391224759393748, details={'was_impossible': False}),
#  Prediction(uid='588', iid='751', r_ui=3.0, est=3.413294150320574, details={'was_impossible': False}),
#  Prediction(uid='837', iid='294', r_ui=4.0, est=2.758452683183329, details={'was_impossible': False}),
#  Prediction(uid='178', iid='124', r_ui=4.0, est=3.873528528080291, details={'was_impossible': False}),
#  Prediction(uid='587', iid='875', r_ui=1.0, est=2.788033890912965, details={'was_impossible': False}),
#  Prediction(uid='938', iid='873', r_ui=3.0, est=3.6888895848646137, details={'was_impossible': False}),
#  Prediction(uid='727', iid='1218', r_ui=4.0, est=3.14381245303216, details={'was_impossible': False}),
#  Prediction(uid='807', iid='405', r_ui=4.0, est=3.569810983989834, details={'was_impossible': False}),
#  Prediction(uid='58', iid='1097', r_ui=5.0, est=3.2827241206747266, details={'was_impossible': False}),
#  Prediction(uid='277', iid='151', r_ui=3.0, est=3.45017640102, details={'was_impossible': False}),
#  Prediction(uid='756', iid='403', r_ui=2.0, est=3.7225153634477515, details={'was_impossible': False}),
#  Prediction(uid='474', iid='151', r_ui=3.0, est=4.29639495821176, details={'was_impossible': False}),
#  Prediction(uid='561', iid='410', r_ui=1.0, est=3.1693037013783547, details={'was_impossible': False}),
#  Prediction(uid='276', iid='742', r_ui=4.0, est=3.348034684219453, details={'was_impossible': False}),
#  Prediction(uid='426', iid='50', r_ui=4.0, est=3.8871676359216982, details={'was_impossible': False}),
#  Prediction(uid='733', iid='740', r_ui=3.0, est=2.951794640772992, details={'was_impossible': False}),
#  Prediction(uid='753', iid='304', r_ui=4.0, est=3.2237850498432707, details={'was_impossible': False}),
#  Prediction(uid='198', iid='127', r_ui=5.0, est=4.201190802929259, details={'was_impossible': False}),
#  Prediction(uid='60', iid='641', r_ui=5.0, est=4.060699253800686, details={'was_impossible': False}),
#  Prediction(uid='890', iid='127', r_ui=5.0, est=4.3680220089030835, details={'was_impossible': False}),
#  Prediction(uid='379', iid='1035', r_ui=3.0, est=3.8137374511353723, details={'was_impossible': False}),
#  Prediction(uid='707', iid='692', r_ui=4.0, est=3.946876368241832, details={'was_impossible': False}),
#  Prediction(uid='940', iid='343', r_ui=2.0, est=3.42685433418385, details={'was_impossible': False}),
#  Prediction(uid='796', iid='783', r_ui=4.0, est=3.4466677389521396, details={'was_impossible': False}),
#  Prediction(uid='326', iid='679', r_ui=3.0, est=2.978060517984834, details={'was_impossible': False}),
#  Prediction(uid='338', iid='480', r_ui=5.0, est=4.436101577326021, details={'was_impossible': False}),
#  Prediction(uid='129', iid='906', r_ui=5.0, est=3.7293114373340615, details={'was_impossible': False}),
#  Prediction(uid='345', iid='628', r_ui=3.0, est=3.3307005016815427, details={'was_impossible': False}),
#  Prediction(uid='815', iid='79', r_ui=4.0, est=4.191933683863431, details={'was_impossible': False}),
#  Prediction(uid='361', iid='156', r_ui=4.0, est=3.9718755919092543, details={'was_impossible': False}),
#  Prediction(uid='320', iid='195', r_ui=5.0, est=4.868654531522025, details={'was_impossible': False}),
#  Prediction(uid='276', iid='291', r_ui=3.0, est=3.3646989069136146, details={'was_impossible': False}),
#  Prediction(uid='605', iid='210', r_ui=3.0, est=3.9346219022011906, details={'was_impossible': False}),
#  Prediction(uid='552', iid='845', r_ui=3.0, est=3.5142425360899083, details={'was_impossible': False}),
#  Prediction(uid='915', iid='1038', r_ui=2.0, est=2.9049649168033347, details={'was_impossible': False}),
#  Prediction(uid='586', iid='54', r_ui=3.0, est=3.08443129509592, details={'was_impossible': False}),
#  Prediction(uid='846', iid='175', r_ui=5.0, est=3.5319999241249267, details={'was_impossible': False}),
#  Prediction(uid='389', iid='286', r_ui=2.0, est=4.466558621476647, details={'was_impossible': False}),
#  Prediction(uid='806', iid='158', r_ui=2.0, est=2.859357371336778, details={'was_impossible': False}),
#  Prediction(uid='563', iid='294', r_ui=3.0, est=3.56158322049615, details={'was_impossible': False}),
#  Prediction(uid='378', iid='230', r_ui=3.0, est=3.7527584485665084, details={'was_impossible': False}),
#  Prediction(uid='860', iid='257', r_ui=3.0, est=3.7763777188538787, details={'was_impossible': False}),
#  Prediction(uid='393', iid='202', r_ui=3.0, est=4.012345955968004, details={'was_impossible': False}),
#  Prediction(uid='336', iid='579', r_ui=3.0, est=2.6349688112369174, details={'was_impossible': False}),
#  Prediction(uid='738', iid='496', r_ui=4.0, est=4.188147875684439, details={'was_impossible': False}),
#  Prediction(uid='7', iid='664', r_ui=3.0, est=3.926627884332492, details={'was_impossible': False}),
#  Prediction(uid='506', iid='792', r_ui=2.0, est=3.420455456154842, details={'was_impossible': False}),
#  Prediction(uid='788', iid='118', r_ui=3.0, est=3.8239065131016825, details={'was_impossible': False}),
#  Prediction(uid='376', iid='663', r_ui=3.0, est=3.628015253053575, details={'was_impossible': False}),
#  Prediction(uid='486', iid='269', r_ui=4.0, est=3.74282888421545, details={'was_impossible': False}),
#  Prediction(uid='95', iid='195', r_ui=5.0, est=4.166242214852337, details={'was_impossible': False}),
#  Prediction(uid='234', iid='648', r_ui=3.0, est=3.1444118188239853, details={'was_impossible': False}),
#  Prediction(uid='201', iid='1100', r_ui=4.0, est=2.6035293295599953, details={'was_impossible': False}),
#  Prediction(uid='880', iid='272', r_ui=5.0, est=4.37681831177919, details={'was_impossible': False}),
#  Prediction(uid='76', iid='89', r_ui=4.0, est=4.160839272341669, details={'was_impossible': False}),
#  Prediction(uid='851', iid='696', r_ui=3.0, est=3.051831753456059, details={'was_impossible': False}),
#  Prediction(uid='721', iid='872', r_ui=3.0, est=3.215929169313014, details={'was_impossible': False}),
#  Prediction(uid='234', iid='313', r_ui=4.0, est=3.4909216101892357, details={'was_impossible': False}),
#  Prediction(uid='354', iid='9', r_ui=3.0, est=3.902488959423813, details={'was_impossible': False}),
#  Prediction(uid='796', iid='22', r_ui=4.0, est=4.634024134902826, details={'was_impossible': False}),
#  Prediction(uid='174', iid='724', r_ui=5.0, est=3.7651876659399512, details={'was_impossible': False}),
#  Prediction(uid='653', iid='679', r_ui=2.0, est=2.1293517543437845, details={'was_impossible': False}),
#  Prediction(uid='934', iid='135', r_ui=4.0, est=3.7846081842257626, details={'was_impossible': False}),
#  Prediction(uid='717', iid='343', r_ui=4.0, est=3.6560816723493685, details={'was_impossible': False}),
#  Prediction(uid='144', iid='963', r_ui=4.0, est=4.202290515833736, details={'was_impossible': False}),
#  Prediction(uid='474', iid='405', r_ui=4.0, est=3.7836852724851715, details={'was_impossible': False}),
#  Prediction(uid='757', iid='405', r_ui=4.0, est=3.0942033807264355, details={'was_impossible': False}),
#  Prediction(uid='846', iid='178', r_ui=4.0, est=4.081232728301499, details={'was_impossible': False}),
#  Prediction(uid='504', iid='291', r_ui=4.0, est=3.9705552184058646, details={'was_impossible': False}),
#  Prediction(uid='656', iid='322', r_ui=1.0, est=2.8168854472762295, details={'was_impossible': False}),
#  Prediction(uid='664', iid='528', r_ui=5.0, est=3.799667931551378, details={'was_impossible': False}),
#  Prediction(uid='551', iid='384', r_ui=1.0, est=2.893637720725022, details={'was_impossible': False}),
#  Prediction(uid='454', iid='286', r_ui=3.0, est=3.304273546668503, details={'was_impossible': False}),
#  Prediction(uid='171', iid='262', r_ui=4.0, est=3.511407549895593, details={'was_impossible': False}),
#  Prediction(uid='551', iid='979', r_ui=4.0, est=4.091831702487471, details={'was_impossible': False}),
#  Prediction(uid='745', iid='258', r_ui=5.0, est=3.348037503846813, details={'was_impossible': False}),
#  Prediction(uid='889', iid='762', r_ui=3.0, est=3.0515205107028556, details={'was_impossible': False}),
#  Prediction(uid='913', iid='237', r_ui=4.0, est=3.635442876383683, details={'was_impossible': False}),
#  Prediction(uid='32', iid='455', r_ui=2.0, est=2.9077027155526993, details={'was_impossible': False}),
#  Prediction(uid='532', iid='295', r_ui=5.0, est=4.19396735818236, details={'was_impossible': False}),
#  Prediction(uid='57', iid='105', r_ui=3.0, est=3.1462300858397625, details={'was_impossible': False}),
#  Prediction(uid='924', iid='433', r_ui=5.0, est=4.063159539867909, details={'was_impossible': False}),
#  Prediction(uid='13', iid='878', r_ui=1.0, est=2.591436403594057, details={'was_impossible': False}),
#  Prediction(uid='653', iid='480', r_ui=4.0, est=3.842477026841902, details={'was_impossible': False}),
#  Prediction(uid='35', iid='261', r_ui=3.0, est=2.1249399819510124, details={'was_impossible': False}),
#  Prediction(uid='795', iid='825', r_ui=2.0, est=2.5490850500649547, details={'was_impossible': False}),
#  Prediction(uid='913', iid='408', r_ui=5.0, est=3.7728606491341923, details={'was_impossible': False}),
#  Prediction(uid='688', iid='326', r_ui=5.0, est=4.589282398588984, details={'was_impossible': False}),
#  Prediction(uid='405', iid='23', r_ui=5.0, est=1.847333492295654, details={'was_impossible': False}),
#  Prediction(uid='665', iid='274', r_ui=3.0, est=3.4245762646263898, details={'was_impossible': False}),
#  Prediction(uid='49', iid='346', r_ui=4.0, est=2.884628680694469, details={'was_impossible': False}),
#  Prediction(uid='313', iid='519', r_ui=5.0, est=4.3986972125843735, details={'was_impossible': False}),
#  Prediction(uid='169', iid='321', r_ui=3.0, est=3.5081841549763357, details={'was_impossible': False}),
#  Prediction(uid='1', iid='270', r_ui=5.0, est=3.5470672561118715, details={'was_impossible': False}),
#  Prediction(uid='643', iid='262', r_ui=3.0, est=4.242443298798699, details={'was_impossible': False}),
#  Prediction(uid='201', iid='1166', r_ui=3.0, est=3.0747560925702406, details={'was_impossible': False}),
#  Prediction(uid='385', iid='671', r_ui=3.0, est=3.460999974259238, details={'was_impossible': False}),
#  Prediction(uid='794', iid='127', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='114', iid='197', r_ui=4.0, est=3.813034279341505, details={'was_impossible': False}),
#  Prediction(uid='503', iid='69', r_ui=4.0, est=4.308189329939337, details={'was_impossible': False}),
#  Prediction(uid='833', iid='1019', r_ui=5.0, est=3.4240045980999763, details={'was_impossible': False}),
#  Prediction(uid='92', iid='411', r_ui=4.0, est=2.542650475588155, details={'was_impossible': False}),
#  Prediction(uid='551', iid='5', r_ui=4.0, est=3.623408208920911, details={'was_impossible': False}),
#  Prediction(uid='397', iid='991', r_ui=1.0, est=2.829344983827827, details={'was_impossible': False}),
#  Prediction(uid='1', iid='76', r_ui=4.0, est=3.592089417975839, details={'was_impossible': False}),
#  Prediction(uid='227', iid='1010', r_ui=3.0, est=3.372213382952832, details={'was_impossible': False}),
#  Prediction(uid='527', iid='423', r_ui=3.0, est=3.6043350042110767, details={'was_impossible': False}),
#  Prediction(uid='73', iid='81', r_ui=5.0, est=3.8020423273177615, details={'was_impossible': False}),
#  Prediction(uid='826', iid='422', r_ui=2.0, est=3.592035900671635, details={'was_impossible': False}),
#  Prediction(uid='725', iid='1197', r_ui=3.0, est=3.999171925178094, details={'was_impossible': False}),
#  Prediction(uid='94', iid='177', r_ui=5.0, est=4.336763940849979, details={'was_impossible': False}),
#  Prediction(uid='160', iid='497', r_ui=4.0, est=3.7344363177931053, details={'was_impossible': False}),
#  Prediction(uid='193', iid='368', r_ui=1.0, est=2.3698034601643347, details={'was_impossible': False}),
#  Prediction(uid='560', iid='617', r_ui=3.0, est=3.4560294203413435, details={'was_impossible': False}),
#  Prediction(uid='456', iid='523', r_ui=4.0, est=3.7242653415112827, details={'was_impossible': False}),
#  Prediction(uid='796', iid='693', r_ui=3.0, est=3.946528196429047, details={'was_impossible': False}),
#  Prediction(uid='536', iid='275', r_ui=5.0, est=3.947576864492319, details={'was_impossible': False}),
#  Prediction(uid='577', iid='38', r_ui=2.0, est=3.268896676906776, details={'was_impossible': False}),
#  Prediction(uid='805', iid='545', r_ui=1.0, est=2.9827051623656105, details={'was_impossible': False}),
#  Prediction(uid='311', iid='515', r_ui=4.0, est=4.509081484027192, details={'was_impossible': False}),
#  Prediction(uid='354', iid='724', r_ui=2.0, est=4.089330295312907, details={'was_impossible': False}),
#  Prediction(uid='566', iid='215', r_ui=3.0, est=3.2551541790457144, details={'was_impossible': False}),
#  Prediction(uid='230', iid='69', r_ui=4.0, est=4.456626423599921, details={'was_impossible': False}),
#  Prediction(uid='264', iid='516', r_ui=5.0, est=4.34355123947775, details={'was_impossible': False}),
#  Prediction(uid='862', iid='173', r_ui=5.0, est=4.573663686345921, details={'was_impossible': False}),
#  Prediction(uid='645', iid='616', r_ui=3.0, est=3.595638424850485, details={'was_impossible': False}),
#  Prediction(uid='818', iid='313', r_ui=4.0, est=4.177309646703491, details={'was_impossible': False}),
#  Prediction(uid='743', iid='322', r_ui=3.0, est=3.4104909267832233, details={'was_impossible': False}),
#  Prediction(uid='567', iid='268', r_ui=4.0, est=4.144186676665042, details={'was_impossible': False}),
#  Prediction(uid='200', iid='179', r_ui=4.0, est=4.152447086493427, details={'was_impossible': False}),
#  Prediction(uid='437', iid='172', r_ui=4.0, est=4.206504705585865, details={'was_impossible': False}),
#  Prediction(uid='272', iid='746', r_ui=3.0, est=4.170412260243688, details={'was_impossible': False}),
#  Prediction(uid='552', iid='515', r_ui=3.0, est=3.5370720753745424, details={'was_impossible': False}),
#  Prediction(uid='338', iid='1', r_ui=3.0, est=3.8177057138603416, details={'was_impossible': False}),
#  Prediction(uid='276', iid='62', r_ui=2.0, est=3.3967123280205316, details={'was_impossible': False}),
#  Prediction(uid='788', iid='301', r_ui=2.0, est=3.138560475353237, details={'was_impossible': False}),
#  Prediction(uid='249', iid='252', r_ui=2.0, est=2.7939416485816357, details={'was_impossible': False}),
#  Prediction(uid='942', iid='117', r_ui=4.0, est=4.0279117215494304, details={'was_impossible': False}),
#  Prediction(uid='767', iid='478', r_ui=4.0, est=4.6063048271287785, details={'was_impossible': False}),
#  Prediction(uid='543', iid='576', r_ui=4.0, est=2.7633560406744238, details={'was_impossible': False}),
#  Prediction(uid='85', iid='654', r_ui=4.0, est=4.111971791145578, details={'was_impossible': False}),
#  Prediction(uid='405', iid='746', r_ui=1.0, est=2.8566275556815963, details={'was_impossible': False}),
#  Prediction(uid='543', iid='528', r_ui=4.0, est=3.730001786567252, details={'was_impossible': False}),
#  Prediction(uid='450', iid='549', r_ui=3.0, est=3.6335550886324106, details={'was_impossible': False}),
#  Prediction(uid='135', iid='1217', r_ui=2.0, est=3.426565740454431, details={'was_impossible': False}),
#  Prediction(uid='554', iid='4', r_ui=2.0, est=3.1071183077378497, details={'was_impossible': False}),
#  Prediction(uid='741', iid='226', r_ui=2.0, est=3.800043385947756, details={'was_impossible': False}),
#  Prediction(uid='836', iid='507', r_ui=4.0, est=3.429326633873713, details={'was_impossible': False}),
#  Prediction(uid='749', iid='650', r_ui=3.0, est=3.4872395683047515, details={'was_impossible': False}),
#  Prediction(uid='491', iid='23', r_ui=2.0, est=3.9063395869697297, details={'was_impossible': False}),
#  Prediction(uid='7', iid='141', r_ui=5.0, est=4.202273654846861, details={'was_impossible': False}),
#  Prediction(uid='537', iid='744', r_ui=3.0, est=2.7884857836704677, details={'was_impossible': False}),
#  Prediction(uid='582', iid='313', r_ui=5.0, est=4.216345142569845, details={'was_impossible': False}),
#  Prediction(uid='214', iid='173', r_ui=4.0, est=3.6286342822489046, details={'was_impossible': False}),
#  Prediction(uid='790', iid='944', r_ui=1.0, est=2.6977198789337846, details={'was_impossible': False}),
#  Prediction(uid='425', iid='227', r_ui=4.0, est=2.851349573775522, details={'was_impossible': False}),
#  Prediction(uid='862', iid='201', r_ui=3.0, est=4.059116628142696, details={'was_impossible': False}),
#  Prediction(uid='201', iid='12', r_ui=4.0, est=3.798049713746954, details={'was_impossible': False}),
#  Prediction(uid='323', iid='293', r_ui=4.0, est=3.7924414687267745, details={'was_impossible': False}),
#  Prediction(uid='429', iid='596', r_ui=3.0, est=3.1723867312102128, details={'was_impossible': False}),
#  Prediction(uid='688', iid='682', r_ui=5.0, est=3.263482877687985, details={'was_impossible': False}),
#  Prediction(uid='326', iid='8', r_ui=4.0, est=3.491601747447467, details={'was_impossible': False}),
#  Prediction(uid='613', iid='1', r_ui=4.0, est=4.887172719702733, details={'was_impossible': False}),
#  Prediction(uid='214', iid='276', r_ui=3.0, est=4.314311143461001, details={'was_impossible': False}),
#  Prediction(uid='829', iid='319', r_ui=4.0, est=2.8787778391174412, details={'was_impossible': False}),
#  Prediction(uid='347', iid='96', r_ui=4.0, est=3.9836738790351087, details={'was_impossible': False}),
#  Prediction(uid='221', iid='780', r_ui=3.0, est=3.2646980428188135, details={'was_impossible': False}),
#  Prediction(uid='702', iid='751', r_ui=4.0, est=3.808070804296827, details={'was_impossible': False}),
#  Prediction(uid='606', iid='1190', r_ui=3.0, est=3.9834642380489713, details={'was_impossible': False}),
#  Prediction(uid='875', iid='479', r_ui=4.0, est=4.462957296689872, details={'was_impossible': False}),
#  Prediction(uid='340', iid='969', r_ui=5.0, est=3.2364195191259495, details={'was_impossible': False}),
#  Prediction(uid='417', iid='217', r_ui=4.0, est=3.3942146957717814, details={'was_impossible': False}),
#  Prediction(uid='1', iid='172', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='655', iid='345', r_ui=3.0, est=2.7259714807569564, details={'was_impossible': False}),
#  Prediction(uid='551', iid='1067', r_ui=2.0, est=4.028620929791264, details={'was_impossible': False}),
#  Prediction(uid='332', iid='1028', r_ui=4.0, est=3.56552578606657, details={'was_impossible': False}),
#  Prediction(uid='297', iid='582', r_ui=4.0, est=3.7991404747947892, details={'was_impossible': False}),
#  Prediction(uid='450', iid='336', r_ui=3.0, est=3.257289337005649, details={'was_impossible': False}),
#  Prediction(uid='424', iid='882', r_ui=3.0, est=3.5055950977115486, details={'was_impossible': False}),
#  Prediction(uid='327', iid='89', r_ui=4.0, est=3.5035782305054006, details={'was_impossible': False}),
#  Prediction(uid='549', iid='323', r_ui=2.0, est=2.73715566800779, details={'was_impossible': False}),
#  Prediction(uid='151', iid='190', r_ui=4.0, est=4.0892952250973575, details={'was_impossible': False}),
#  Prediction(uid='234', iid='436', r_ui=3.0, est=3.107718073473571, details={'was_impossible': False}),
#  Prediction(uid='38', iid='70', r_ui=5.0, est=3.478320099983091, details={'was_impossible': False}),
#  Prediction(uid='514', iid='259', r_ui=4.0, est=2.7360012285666224, details={'was_impossible': False}),
#  Prediction(uid='458', iid='284', r_ui=4.0, est=2.8233222193153207, details={'was_impossible': False}),
#  Prediction(uid='758', iid='353', r_ui=4.0, est=3.1479812574835866, details={'was_impossible': False}),
#  Prediction(uid='249', iid='161', r_ui=3.0, est=3.946631681437818, details={'was_impossible': False}),
#  Prediction(uid='180', iid='202', r_ui=3.0, est=3.847733930512611, details={'was_impossible': False}),
#  Prediction(uid='719', iid='318', r_ui=5.0, est=3.464988193108299, details={'was_impossible': False}),
#  Prediction(uid='864', iid='8', r_ui=5.0, est=4.261930421433705, details={'was_impossible': False}),
#  Prediction(uid='501', iid='597', r_ui=3.0, est=3.73014401382001, details={'was_impossible': False}),
#  Prediction(uid='916', iid='423', r_ui=3.0, est=3.543292999565602, details={'was_impossible': False}),
#  Prediction(uid='70', iid='176', r_ui=4.0, est=4.3915149360097345, details={'was_impossible': False}),
#  Prediction(uid='83', iid='118', r_ui=3.0, est=3.268998723955392, details={'was_impossible': False}),
#  Prediction(uid='417', iid='679', r_ui=2.0, est=3.442851902892705, details={'was_impossible': False}),
#  Prediction(uid='311', iid='501', r_ui=5.0, est=3.5775152391153804, details={'was_impossible': False}),
#  Prediction(uid='92', iid='715', r_ui=4.0, est=3.197409043017291, details={'was_impossible': False}),
#  Prediction(uid='360', iid='56', r_ui=4.0, est=4.605034753313991, details={'was_impossible': False}),
#  Prediction(uid='763', iid='133', r_ui=3.0, est=3.704539466131701, details={'was_impossible': False}),
#  Prediction(uid='619', iid='245', r_ui=4.0, est=3.07854111739013, details={'was_impossible': False}),
#  Prediction(uid='774', iid='1182', r_ui=1.0, est=2.422620433678924, details={'was_impossible': False}),
#  Prediction(uid='662', iid='100', r_ui=5.0, est=3.7146316432203546, details={'was_impossible': False}),
#  Prediction(uid='748', iid='709', r_ui=4.0, est=3.732934300580807, details={'was_impossible': False}),
#  Prediction(uid='334', iid='461', r_ui=3.0, est=3.389225726776166, details={'was_impossible': False}),
#  Prediction(uid='796', iid='623', r_ui=3.0, est=3.1000137525670213, details={'was_impossible': False}),
#  Prediction(uid='145', iid='379', r_ui=3.0, est=2.9671081514626567, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1118', r_ui=4.0, est=3.1509594449548386, details={'was_impossible': False}),
#  Prediction(uid='11', iid='720', r_ui=1.0, est=2.9272058545640176, details={'was_impossible': False}),
#  Prediction(uid='222', iid='568', r_ui=5.0, est=3.1596640474171456, details={'was_impossible': False}),
#  Prediction(uid='405', iid='1228', r_ui=1.0, est=1.2532574831765628, details={'was_impossible': False}),
#  Prediction(uid='690', iid='66', r_ui=3.0, est=3.7116669189838327, details={'was_impossible': False}),
#  Prediction(uid='207', iid='655', r_ui=4.0, est=3.714622430962722, details={'was_impossible': False}),
#  Prediction(uid='236', iid='435', r_ui=4.0, est=3.633439031887996, details={'was_impossible': False}),
#  Prediction(uid='328', iid='447', r_ui=2.0, est=3.292019252229392, details={'was_impossible': False}),
#  Prediction(uid='771', iid='97', r_ui=1.0, est=3.9259349454377093, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1025', r_ui=1.0, est=1.2282907708637476, details={'was_impossible': False}),
#  Prediction(uid='224', iid='215', r_ui=4.0, est=3.9930429059135486, details={'was_impossible': False}),
#  Prediction(uid='271', iid='12', r_ui=4.0, est=4.539021347440488, details={'was_impossible': False}),
#  Prediction(uid='380', iid='729', r_ui=3.0, est=2.9724337961310052, details={'was_impossible': False}),
#  Prediction(uid='309', iid='258', r_ui=5.0, est=3.7244588541276746, details={'was_impossible': False}),
#  Prediction(uid='303', iid='872', r_ui=3.0, est=3.298424940208532, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1535', r_ui=3.0, est=2.9855123984521144, details={'was_impossible': False}),
#  Prediction(uid='293', iid='194', r_ui=4.0, est=3.4496284032325013, details={'was_impossible': False}),
#  Prediction(uid='437', iid='654', r_ui=5.0, est=4.16233295839039, details={'was_impossible': False}),
#  Prediction(uid='844', iid='168', r_ui=4.0, est=4.195977017833119, details={'was_impossible': False}),
#  Prediction(uid='10', iid='185', r_ui=5.0, est=4.582116799322338, details={'was_impossible': False}),
#  Prediction(uid='254', iid='662', r_ui=4.0, est=3.4109687963442203, details={'was_impossible': False}),
#  Prediction(uid='792', iid='1132', r_ui=3.0, est=3.23729017723213, details={'was_impossible': False}),
#  Prediction(uid='775', iid='312', r_ui=3.0, est=3.079081078343994, details={'was_impossible': False}),
#  Prediction(uid='13', iid='83', r_ui=2.0, est=3.6924828673038674, details={'was_impossible': False}),
#  Prediction(uid='78', iid='813', r_ui=2.0, est=4.190698371793168, details={'was_impossible': False}),
#  Prediction(uid='854', iid='744', r_ui=2.0, est=2.8188344092519015, details={'was_impossible': False}),
#  Prediction(uid='393', iid='12', r_ui=5.0, est=3.8446716394561884, details={'was_impossible': False}),
#  Prediction(uid='869', iid='269', r_ui=4.0, est=3.6795001224008326, details={'was_impossible': False}),
#  Prediction(uid='207', iid='628', r_ui=3.0, est=3.263237683382792, details={'was_impossible': False}),
#  Prediction(uid='416', iid='931', r_ui=3.0, est=2.9531053976026866, details={'was_impossible': False}),
#  Prediction(uid='746', iid='231', r_ui=2.0, est=3.205855514828901, details={'was_impossible': False}),
#  Prediction(uid='497', iid='840', r_ui=3.0, est=2.9801237411353374, details={'was_impossible': False}),
#  Prediction(uid='847', iid='1160', r_ui=4.0, est=3.4529708172604847, details={'was_impossible': False}),
#  Prediction(uid='554', iid='527', r_ui=4.0, est=4.123081506988661, details={'was_impossible': False}),
#  Prediction(uid='488', iid='692', r_ui=4.0, est=3.379457861352882, details={'was_impossible': False}),
#  Prediction(uid='269', iid='316', r_ui=4.0, est=4.056796122617262, details={'was_impossible': False}),
#  Prediction(uid='622', iid='198', r_ui=4.0, est=3.7518591837510247, details={'was_impossible': False}),
#  Prediction(uid='85', iid='286', r_ui=4.0, est=3.5692185542588377, details={'was_impossible': False}),
#  Prediction(uid='150', iid='325', r_ui=1.0, est=3.186304221831984, details={'was_impossible': False}),
#  Prediction(uid='921', iid='760', r_ui=2.0, est=2.709203510221809, details={'was_impossible': False}),
#  Prediction(uid='303', iid='544', r_ui=4.0, est=3.617440423349517, details={'was_impossible': False}),
#  Prediction(uid='582', iid='271', r_ui=4.0, est=3.227679431370048, details={'was_impossible': False}),
#  Prediction(uid='389', iid='133', r_ui=5.0, est=3.454964351046573, details={'was_impossible': False}),
#  Prediction(uid='577', iid='742', r_ui=4.0, est=3.6476644570400656, details={'was_impossible': False}),
#  Prediction(uid='911', iid='548', r_ui=3.0, est=3.0159916884110896, details={'was_impossible': False}),
#  Prediction(uid='655', iid='288', r_ui=3.0, est=2.855012398997186, details={'was_impossible': False}),
#  Prediction(uid='90', iid='64', r_ui=4.0, est=4.626598732957598, details={'was_impossible': False}),
#  Prediction(uid='805', iid='101', r_ui=2.0, est=3.1496980425305035, details={'was_impossible': False}),
#  Prediction(uid='543', iid='515', r_ui=4.0, est=4.477736364429642, details={'was_impossible': False}),
#  Prediction(uid='326', iid='176', r_ui=2.0, est=3.9329282773045486, details={'was_impossible': False}),
#  Prediction(uid='280', iid='202', r_ui=3.0, est=3.5578693497194327, details={'was_impossible': False}),
#  Prediction(uid='387', iid='513', r_ui=5.0, est=3.517675459524348, details={'was_impossible': False}),
#  Prediction(uid='197', iid='538', r_ui=3.0, est=3.2943753442781416, details={'was_impossible': False}),
#  Prediction(uid='592', iid='305', r_ui=4.0, est=3.934117209029719, details={'was_impossible': False}),
#  Prediction(uid='373', iid='28', r_ui=3.0, est=4.101262694491586, details={'was_impossible': False}),
#  Prediction(uid='895', iid='294', r_ui=4.0, est=3.055920598990093, details={'was_impossible': False}),
#  Prediction(uid='643', iid='504', r_ui=4.0, est=3.9550659774972114, details={'was_impossible': False}),
# ...
#  Prediction(uid='313', iid='1066', r_ui=2.0, est=3.0244214425497797, details={'was_impossible': False}),
#  Prediction(uid='918', iid='1266', r_ui=4.0, est=3.3564447968035904, details={'was_impossible': False}),
#  Prediction(uid='640', iid='38', r_ui=4.0, est=3.367726426651005, details={'was_impossible': False}),
#  Prediction(uid='929', iid='28', r_ui=4.0, est=4.175698612107687, details={'was_impossible': False}),
#  Prediction(uid='373', iid='211', r_ui=4.0, est=3.774747937129452, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1373', r_ui=1.0, est=1.8088308211832462, details={'was_impossible': False}),
#  Prediction(uid='167', iid='235', r_ui=3.0, est=3.3173035487578657, details={'was_impossible': False}),
#  Prediction(uid='650', iid='504', r_ui=3.0, est=3.535638772923159, details={'was_impossible': False}),
#  Prediction(uid='65', iid='125', r_ui=4.0, est=3.9776510668416516, details={'was_impossible': False}),
#  Prediction(uid='643', iid='68', r_ui=3.0, est=3.350292556928115, details={'was_impossible': False}),
#  Prediction(uid='158', iid='866', r_ui=2.0, est=3.32093437018335, details={'was_impossible': False}),
#  Prediction(uid='504', iid='322', r_ui=4.0, est=3.005064939832658, details={'was_impossible': False}),
#  Prediction(uid='13', iid='636', r_ui=2.0, est=2.8015927356385233, details={'was_impossible': False}),
#  Prediction(uid='776', iid='947', r_ui=2.0, est=3.8971475644511124, details={'was_impossible': False}),
#  Prediction(uid='897', iid='202', r_ui=2.0, est=4.259063323660033, details={'was_impossible': False}),
#  Prediction(uid='182', iid='150', r_ui=3.0, est=4.265537978699077, details={'was_impossible': False}),
#  Prediction(uid='130', iid='366', r_ui=5.0, est=4.257420529560809, details={'was_impossible': False}),
#  Prediction(uid='894', iid='1023', r_ui=3.0, est=2.671761918650076, details={'was_impossible': False}),
#  Prediction(uid='293', iid='1421', r_ui=2.0, est=3.2489104625720975, details={'was_impossible': False}),
#  Prediction(uid='13', iid='850', r_ui=4.0, est=3.760271420456855, details={'was_impossible': False}),
#  Prediction(uid='91', iid='131', r_ui=2.0, est=4.671129445197927, details={'was_impossible': False}),
#  Prediction(uid='11', iid='690', r_ui=4.0, est=3.52011527702634, details={'was_impossible': False}),
#  Prediction(uid='407', iid='525', r_ui=4.0, est=4.117333929135839, details={'was_impossible': False}),
#  Prediction(uid='355', iid='336', r_ui=4.0, est=3.339724740023399, details={'was_impossible': False}),
#  Prediction(uid='684', iid='82', r_ui=5.0, est=3.3824476156594643, details={'was_impossible': False}),
#  Prediction(uid='44', iid='257', r_ui=4.0, est=3.912144678146498, details={'was_impossible': False}),
#  Prediction(uid='911', iid='381', r_ui=5.0, est=3.7423705539007197, details={'was_impossible': False}),
#  Prediction(uid='660', iid='91', r_ui=4.0, est=3.0285061999160336, details={'was_impossible': False}),
#  Prediction(uid='390', iid='742', r_ui=4.0, est=3.4001501222669748, details={'was_impossible': False}),
#  Prediction(uid='660', iid='101', r_ui=3.0, est=2.4130537653948076, details={'was_impossible': False}),
#  Prediction(uid='564', iid='924', r_ui=3.0, est=3.474547045333775, details={'was_impossible': False}),
#  Prediction(uid='588', iid='762', r_ui=4.0, est=3.14704878717573, details={'was_impossible': False}),
#  Prediction(uid='765', iid='507', r_ui=5.0, est=3.9499245182557265, details={'was_impossible': False}),
#  Prediction(uid='416', iid='142', r_ui=4.0, est=3.589740210777431, details={'was_impossible': False}),
#  Prediction(uid='929', iid='22', r_ui=5.0, est=4.217808417047587, details={'was_impossible': False}),
#  Prediction(uid='620', iid='699', r_ui=5.0, est=4.379897493536339, details={'was_impossible': False}),
#  Prediction(uid='303', iid='375', r_ui=2.0, est=2.6204398864741947, details={'was_impossible': False}),
#  Prediction(uid='401', iid='815', r_ui=3.0, est=3.1958813180279604, details={'was_impossible': False}),
#  Prediction(uid='399', iid='176', r_ui=3.0, est=3.4031032321036045, details={'was_impossible': False}),
#  Prediction(uid='276', iid='109', r_ui=4.0, est=3.5136830407627335, details={'was_impossible': False}),
#  Prediction(uid='815', iid='1078', r_ui=2.0, est=3.481101859264408, details={'was_impossible': False}),
#  Prediction(uid='519', iid='1617', r_ui=5.0, est=3.226875739516419, details={'was_impossible': False}),
#  Prediction(uid='423', iid='322', r_ui=3.0, est=3.025918633823066, details={'was_impossible': False}),
#  Prediction(uid='98', iid='523', r_ui=5.0, est=4.14621479477098, details={'was_impossible': False}),
#  Prediction(uid='102', iid='99', r_ui=2.0, est=3.164399060990885, details={'was_impossible': False}),
#  Prediction(uid='867', iid='295', r_ui=4.0, est=4.021158727429017, details={'was_impossible': False}),
#  Prediction(uid='235', iid='1021', r_ui=5.0, est=3.2011116556916304, details={'was_impossible': False}),
#  Prediction(uid='708', iid='934', r_ui=4.0, est=2.822295222595546, details={'was_impossible': False}),
#  Prediction(uid='25', iid='174', r_ui=5.0, est=4.6541266181208405, details={'was_impossible': False}),
#  Prediction(uid='653', iid='222', r_ui=3.0, est=2.8622113591254905, details={'was_impossible': False}),
#  Prediction(uid='354', iid='473', r_ui=3.0, est=3.314692299403221, details={'was_impossible': False}),
#  Prediction(uid='249', iid='408', r_ui=5.0, est=4.677773453340366, details={'was_impossible': False}),
#  Prediction(uid='758', iid='898', r_ui=3.0, est=3.3855690253223756, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1379', r_ui=3.0, est=2.551105049531656, details={'was_impossible': False}),
#  Prediction(uid='71', iid='346', r_ui=4.0, est=3.9120204495741637, details={'was_impossible': False}),
#  Prediction(uid='328', iid='349', r_ui=2.0, est=3.2761816575876055, details={'was_impossible': False}),
#  Prediction(uid='474', iid='116', r_ui=5.0, est=4.156646241766714, details={'was_impossible': False}),
#  Prediction(uid='868', iid='480', r_ui=4.0, est=3.8418258059177193, details={'was_impossible': False}),
#  Prediction(uid='70', iid='559', r_ui=3.0, est=3.0380067636891623, details={'was_impossible': False}),
#  Prediction(uid='721', iid='173', r_ui=5.0, est=4.207854857075699, details={'was_impossible': False}),
#  Prediction(uid='872', iid='476', r_ui=4.0, est=3.2635438764024265, details={'was_impossible': False}),
#  Prediction(uid='456', iid='274', r_ui=3.0, est=3.8172692961428245, details={'was_impossible': False}),
#  Prediction(uid='567', iid='181', r_ui=1.0, est=3.258195446136852, details={'was_impossible': False}),
#  Prediction(uid='943', iid='559', r_ui=4.0, est=3.1179599542193572, details={'was_impossible': False}),
#  Prediction(uid='881', iid='88', r_ui=3.0, est=4.16748137894035, details={'was_impossible': False}),
#  Prediction(uid='636', iid='10', r_ui=5.0, est=4.1035931233255365, details={'was_impossible': False}),
#  Prediction(uid='301', iid='138', r_ui=2.0, est=3.1031737623125935, details={'was_impossible': False}),
#  Prediction(uid='201', iid='213', r_ui=4.0, est=3.3654342209698624, details={'was_impossible': False}),
#  Prediction(uid='938', iid='1013', r_ui=2.0, est=2.8611288318558685, details={'was_impossible': False}),
#  Prediction(uid='308', iid='211', r_ui=4.0, est=3.999590897543381, details={'was_impossible': False}),
#  Prediction(uid='738', iid='1047', r_ui=3.0, est=3.262753927923625, details={'was_impossible': False}),
#  Prediction(uid='379', iid='8', r_ui=5.0, est=3.6391395588978424, details={'was_impossible': False}),
#  Prediction(uid='89', iid='240', r_ui=4.0, est=3.511022951940639, details={'was_impossible': False}),
#  Prediction(uid='437', iid='30', r_ui=4.0, est=3.8766307672736002, details={'was_impossible': False}),
#  Prediction(uid='663', iid='508', r_ui=4.0, est=2.892279440073544, details={'was_impossible': False}),
#  Prediction(uid='205', iid='1025', r_ui=1.0, est=3.2493745949679225, details={'was_impossible': False}),
#  Prediction(uid='201', iid='380', r_ui=1.0, est=2.7453461185191403, details={'was_impossible': False}),
#  Prediction(uid='276', iid='463', r_ui=4.0, est=3.452498728471955, details={'was_impossible': False}),
#  Prediction(uid='756', iid='323', r_ui=3.0, est=2.7525389707238723, details={'was_impossible': False}),
#  Prediction(uid='805', iid='108', r_ui=3.0, est=3.533842208413495, details={'was_impossible': False}),
#  Prediction(uid='416', iid='686', r_ui=5.0, est=4.21343032771571, details={'was_impossible': False}),
#  Prediction(uid='897', iid='496', r_ui=5.0, est=4.424244715048505, details={'was_impossible': False}),
#  Prediction(uid='764', iid='106', r_ui=2.0, est=2.9120143923596764, details={'was_impossible': False}),
#  Prediction(uid='432', iid='628', r_ui=5.0, est=3.490941207075042, details={'was_impossible': False}),
#  Prediction(uid='18', iid='94', r_ui=3.0, est=3.100226982929053, details={'was_impossible': False}),
#  Prediction(uid='450', iid='155', r_ui=4.0, est=3.454128232402579, details={'was_impossible': False}),
#  Prediction(uid='406', iid='772', r_ui=4.0, est=2.6707050001131147, details={'was_impossible': False}),
#  Prediction(uid='373', iid='1133', r_ui=3.0, est=3.2879912100884052, details={'was_impossible': False}),
#  Prediction(uid='271', iid='951', r_ui=2.0, est=2.3899661455312793, details={'was_impossible': False}),
#  Prediction(uid='480', iid='169', r_ui=5.0, est=3.9403658705450963, details={'was_impossible': False}),
#  Prediction(uid='276', iid='397', r_ui=1.0, est=3.1700231537985557, details={'was_impossible': False}),
#  Prediction(uid='638', iid='510', r_ui=3.0, est=3.5825493354289506, details={'was_impossible': False}),
#  Prediction(uid='99', iid='748', r_ui=4.0, est=3.321207114260833, details={'was_impossible': False}),
#  Prediction(uid='380', iid='313', r_ui=4.0, est=3.945926120886651, details={'was_impossible': False}),
#  Prediction(uid='24', iid='729', r_ui=5.0, est=4.05464074926884, details={'was_impossible': False}),
#  Prediction(uid='618', iid='275', r_ui=3.0, est=3.268658820564521, details={'was_impossible': False}),
#  Prediction(uid='59', iid='710', r_ui=3.0, est=3.7059259223730576, details={'was_impossible': False}),
#  Prediction(uid='478', iid='392', r_ui=2.0, est=3.8434310409690404, details={'was_impossible': False}),
#  Prediction(uid='470', iid='1067', r_ui=4.0, est=3.779370124063198, details={'was_impossible': False}),
#  Prediction(uid='864', iid='276', r_ui=5.0, est=4.273191361230908, details={'was_impossible': False}),
#  Prediction(uid='643', iid='69', r_ui=3.0, est=3.5638515895500644, details={'was_impossible': False}),
#  Prediction(uid='109', iid='172', r_ui=5.0, est=4.345220664750742, details={'was_impossible': False}),
#  Prediction(uid='452', iid='924', r_ui=5.0, est=2.728002783186252, details={'was_impossible': False}),
#  Prediction(uid='529', iid='873', r_ui=4.0, est=3.375264498665905, details={'was_impossible': False}),
#  Prediction(uid='782', iid='264', r_ui=4.0, est=2.7181304753691515, details={'was_impossible': False}),
#  Prediction(uid='811', iid='892', r_ui=4.0, est=3.2161108829372056, details={'was_impossible': False}),
#  Prediction(uid='694', iid='72', r_ui=4.0, est=4.038288520786471, details={'was_impossible': False}),
#  Prediction(uid='929', iid='182', r_ui=4.0, est=3.4046275541450495, details={'was_impossible': False}),
#  Prediction(uid='417', iid='17', r_ui=4.0, est=2.378117705811117, details={'was_impossible': False}),
#  Prediction(uid='712', iid='420', r_ui=3.0, est=4.050617578098612, details={'was_impossible': False}),
#  Prediction(uid='425', iid='576', r_ui=3.0, est=2.3952872522902657, details={'was_impossible': False}),
#  Prediction(uid='308', iid='208', r_ui=4.0, est=3.782456209682943, details={'was_impossible': False}),
#  Prediction(uid='806', iid='271', r_ui=3.0, est=3.216231210073971, details={'was_impossible': False}),
#  Prediction(uid='144', iid='1010', r_ui=3.0, est=2.93875167170951, details={'was_impossible': False}),
#  Prediction(uid='880', iid='930', r_ui=2.0, est=3.07681962112661, details={'was_impossible': False}),
#  Prediction(uid='104', iid='150', r_ui=5.0, est=2.9713832985141213, details={'was_impossible': False}),
#  Prediction(uid='868', iid='114', r_ui=5.0, est=3.6391900438602462, details={'was_impossible': False}),
#  Prediction(uid='160', iid='483', r_ui=5.0, est=4.3762151120985395, details={'was_impossible': False}),
#  Prediction(uid='871', iid='526', r_ui=5.0, est=4.487833204183743, details={'was_impossible': False}),
#  Prediction(uid='707', iid='65', r_ui=4.0, est=3.2865758544430403, details={'was_impossible': False}),
#  Prediction(uid='18', iid='430', r_ui=4.0, est=4.368486431943808, details={'was_impossible': False}),
#  Prediction(uid='290', iid='139', r_ui=2.0, est=2.915791602824208, details={'was_impossible': False}),
#  Prediction(uid='360', iid='879', r_ui=3.0, est=3.3647085080629773, details={'was_impossible': False}),
#  Prediction(uid='3', iid='294', r_ui=2.0, est=2.3062885628813135, details={'was_impossible': False}),
#  Prediction(uid='624', iid='1012', r_ui=4.0, est=3.689469621390361, details={'was_impossible': False}),
#  Prediction(uid='429', iid='1076', r_ui=2.0, est=3.2248929069611494, details={'was_impossible': False}),
#  Prediction(uid='534', iid='825', r_ui=4.0, est=3.5906983939363446, details={'was_impossible': False}),
#  Prediction(uid='526', iid='325', r_ui=3.0, est=3.4474294257243425, details={'was_impossible': False}),
#  Prediction(uid='152', iid='966', r_ui=5.0, est=4.045873701630688, details={'was_impossible': False}),
#  Prediction(uid='189', iid='603', r_ui=5.0, est=4.274644876053351, details={'was_impossible': False}),
#  Prediction(uid='643', iid='928', r_ui=4.0, est=3.6190750639992957, details={'was_impossible': False}),
#  Prediction(uid='246', iid='410', r_ui=1.0, est=2.94948001797885, details={'was_impossible': False}),
#  Prediction(uid='177', iid='568', r_ui=3.0, est=4.080422268997204, details={'was_impossible': False}),
#  Prediction(uid='1', iid='234', r_ui=4.0, est=4.484267046718003, details={'was_impossible': False}),
#  Prediction(uid='887', iid='222', r_ui=3.0, est=4.409241804530324, details={'was_impossible': False}),
#  Prediction(uid='106', iid='77', r_ui=4.0, est=3.223508906962805, details={'was_impossible': False}),
#  Prediction(uid='657', iid='744', r_ui=4.0, est=3.236356146914524, details={'was_impossible': False}),
#  Prediction(uid='359', iid='7', r_ui=5.0, est=3.755913520058921, details={'was_impossible': False}),
#  Prediction(uid='189', iid='60', r_ui=3.0, est=3.9275326234648733, details={'was_impossible': False}),
#  Prediction(uid='276', iid='942', r_ui=4.0, est=3.5866396560901657, details={'was_impossible': False}),
#  Prediction(uid='434', iid='125', r_ui=5.0, est=4.419482121833571, details={'was_impossible': False}),
#  Prediction(uid='295', iid='496', r_ui=5.0, est=4.777687635137271, details={'was_impossible': False}),
#  Prediction(uid='472', iid='367', r_ui=5.0, est=4.514416109088957, details={'was_impossible': False}),
#  Prediction(uid='758', iid='1143', r_ui=5.0, est=4.4668306996021805, details={'was_impossible': False}),
#  Prediction(uid='263', iid='234', r_ui=4.0, est=3.6492224994764677, details={'was_impossible': False}),
#  Prediction(uid='488', iid='429', r_ui=4.0, est=3.356030862044326, details={'was_impossible': False}),
#  Prediction(uid='525', iid='281', r_ui=3.0, est=3.1160833500584673, details={'was_impossible': False}),
#  Prediction(uid='110', iid='258', r_ui=4.0, est=3.380621080436783, details={'was_impossible': False}),
#  Prediction(uid='410', iid='269', r_ui=5.0, est=3.557055694718338, details={'was_impossible': False}),
#  Prediction(uid='497', iid='408', r_ui=4.0, est=4.512176695867781, details={'was_impossible': False}),
#  Prediction(uid='296', iid='151', r_ui=2.0, est=4.2445558414910725, details={'was_impossible': False}),
#  Prediction(uid='450', iid='845', r_ui=4.0, est=3.148187852617578, details={'was_impossible': False}),
#  Prediction(uid='652', iid='333', r_ui=4.0, est=3.0843834997997948, details={'was_impossible': False}),
#  Prediction(uid='95', iid='99', r_ui=4.0, est=3.174582743340845, details={'was_impossible': False}),
#  ...]

# %%
algo.predict(str(321),str(313))
# Out:
# Prediction(uid='321', iid='313', r_ui=None, est=3.9417849643093787, details={'was_impossible': False})

# %%
#Se puede ver que el usuario no le puso rating a la pelicula Titanic pero el modelo precide que es de 3.53 estrellas

# %% [markdown]
# __7) Desarrollar una función que dado un usuario, obtenga la mejor predicción disponible (de acuerdo a nuestros datos de películas).__

# %%
col_names=['user','item','rating','timestamp']
ratings=pd.read_csv('dataset/ml-100k/u.data', sep='\t', names=col_names)

# %%
def mejor_predict(uid):
    watched=ratings[ratings['user']==uid]
    watched=list(watched['item'])
    not_watched = movies[~movies['movie_id'].isin(watched)].iloc[:,0:2]
    not_watched['predictions']=not_watched['movie_id'].apply(lambda x: gs.predict(str(uid),str(x)).est)
    not_watched.sort_values(by='predictions',ascending=False,inplace=True)
    not_watched.reset_index(drop=True,inplace=True)
    movie=not_watched['title'][0]
    rating=not_watched['predictions'][0]
    return print('La mejor predicción es {} con un rating de {}'.format(movie,rating))

# %%
#Ejemplos

# %%
mejor_predict(18)
# Out:
# La mejor predicción es Wallace & Gromit: The Best of Aardman Animation (1996) con un rating de 4.318016593343331

# %%
mejor_predict(313)
# Out:
# La mejor predicción es Close Shave, A (1995) con un rating de 4.243882073412289
